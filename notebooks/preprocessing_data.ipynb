# %%
import pandas as pd
import numpy as np
import os, sys

os.getcwd()
rpath = os.path.abspath('../')
if rpath not in sys.path:
    sys.path.insert(0,rpath)

# %%
train_path = os.path.join(rpath, 'data', 'telegram_data.csv')
data1 = pd.read_csv(train_path)  # Tab-delimited

data1
# Out:
#                                          Channel Title Channel Username    ID  \
# 0    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 1    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 2    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2394
# 3    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2393
# 4    ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2392
# ..                                                 ...              ...   ...
# 468  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1863
# 469  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1862
# 470  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1861
# 471  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1860
# 472  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  1859
#
# ...

# %%
train_path = os.path.join(rpath, 'data', 'telegram_data_chemed.csv')
data2 = pd.read_csv(train_path)  # Tab-delimited

data2
# Out:
#    Channel Title Channel Username  ID  \
# 0         CheMed       @CheMed123  97
# 1         CheMed       @CheMed123  96
# 2         CheMed       @CheMed123  95
# 3         CheMed       @CheMed123  94
# 4         CheMed       @CheMed123  93
# ..           ...              ...  ..
# 71        CheMed       @CheMed123   6
# 72        CheMed       @CheMed123   4
# 73        CheMed       @CheMed123   3
# 74        CheMed       @CheMed123   2
# 75        CheMed       @CheMed123   1
#
#                                               Message  \
# 0   ⚠️Notice!\nDear esteemed customers,\nDue to fo...
# 1   Mela-One በውስጡ ሆርሞን ያለው ድንገተኛ ወሊድ መቆጣጠርያ ሲሆን ያለ...
# 2   አዚትሮማይሲን በሃኪም መድሃኒት ማዘዣ ከሚታዘዙ አንቲባዮቲኮች አንዱ ሲሆን...
# 3   Che-Med Trivia #3\n\nምግብና መጠጦች አንዳንድ መድሃኒቶች በደ...
# 4   Che-Med Trivia #2\n\nእንደ Ciprofloxacin, Doxycy...
# ..                                                ...
# 71                                                NaN
# 72                                                NaN
# ...

# %%
train_path = os.path.join(rpath, 'data', 'telegram_data_doctorset.csv')
data3 = pd.read_csv(train_path)  # Tab-delimited

data3
# Out:
#         Channel Title Channel Username   ID  \
# 0    Doctors Ethiopia       @DoctorsET  864
# 1    Doctors Ethiopia       @DoctorsET  863
# 2    Doctors Ethiopia       @DoctorsET  862
# 3    Doctors Ethiopia       @DoctorsET  861
# 4    Doctors Ethiopia       @DoctorsET  860
# ..                ...              ...  ...
# 798  Doctors Ethiopia       @DoctorsET    7
# 799  Doctors Ethiopia       @DoctorsET    6
# 800  Doctors Ethiopia       @DoctorsET    5
# 801  Doctors Ethiopia       @DoctorsET    3
# 802  Doctors Ethiopia       @DoctorsET    1
#
#                                                Message  \
# 0    https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1    ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2    ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3    ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4    በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# ..                                                 ...
# ...

# %%
train_path = os.path.join(rpath, 'data', 'telegram_data_lobe.csv')
data4 = pd.read_csv(train_path)  # Tab-delimited

data4
# Out:
#                        Channel Title    Channel Username     ID  \
# 0     Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12411
# 1     Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12410
# 2     Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12409
# 3     Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12408
# 4     Lobelia pharmacy and cosmetics  @lobelia4cosmetics  12407
# ...                              ...                 ...    ...
# 2341  Lobelia pharmacy and cosmetics  @lobelia4cosmetics   2646
# 2342  Lobelia pharmacy and cosmetics  @lobelia4cosmetics    998
# 2343  Lobelia pharmacy and cosmetics  @lobelia4cosmetics     71
# 2344  Lobelia pharmacy and cosmetics  @lobelia4cosmetics     40
# 2345  Lobelia pharmacy and cosmetics  @lobelia4cosmetics      1
#
#                                                 Message  \
# 0     EUCERIN PIGMENT CONTROL \nPrice 4500 birr \nTe...
# 1     EUCERIN OIL CONTROL \nPrice 4500 birr \nTelegr...
# ...

# %%
data = pd.concat([data1, data2, data3, data4], ignore_index=True)
data.head()
# Out:
#                                        Channel Title Channel Username    ID  \
# 0  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 1  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 2  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2394
# 3  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2393
# 4  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2392
#
#                                              Message  \
# 0  💥ዛገ ይጀምራል\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ  💥            ...
# 1  💥\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ  💥             \n\n#CP...
# 2                                                NaN
# 3  #Basic_Abdominal_Ultrasound_Training @#Hawassa...
# 4  💥 እንዳያመልጥዎ 💥\n#Obstetric_Ultrasound_Training#A...
#
#                         Date              Media Path
# 0  2024-10-10 13:40:09+00:00  photos\@EAHCI_2396.jpg
# 1  2024-10-09 10:46:24+00:00  photos\@EAHCI_2395.jpg
# ...

# %%
data.isnull().sum()
# Out:
# Channel Title         0
# Channel Username      0
# ID                    0
# Message             407
# Date                  0
# Media Path          498
# dtype: int64

# %%
data = data.fillna(0)
data.head()
# Out:
#                                        Channel Title Channel Username    ID  \
# 0  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 1  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 2  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2394
# 3  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2393
# 4  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2392
#
#                                              Message  \
# 0  💥ዛገ ይጀምራል\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ  💥            ...
# 1  💥\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ  💥             \n\n#CP...
# 2                                                  0
# 3  #Basic_Abdominal_Ultrasound_Training @#Hawassa...
# 4  💥 እንዳያመልጥዎ 💥\n#Obstetric_Ultrasound_Training#A...
#
#                         Date              Media Path
# 0  2024-10-10 13:40:09+00:00  photos\@EAHCI_2396.jpg
# 1  2024-10-09 10:46:24+00:00  photos\@EAHCI_2395.jpg
# ...

# %%
import pandas as pd
import re

# Example DataFrame
# data = pd.DataFrame({'Message': ['💥3pcs silicon brush spatulas...', '💥Mandoline Slicer...', None, 42]})

# Define a function to remove emojis
def remove_emojis(text):
    if isinstance(text, str):  # Check if the text is a string
        emoji_pattern = re.compile(
            "[" 
            "\U0001F600-\U0001F64F"  # emoticons
            "\U0001F300-\U0001F5FF"  # symbols & pictographs
            "\U0001F680-\U0001F6FF"  # transport & map symbols
            "\U0001F700-\U0001F77F"  # alchemical symbols
            "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
            "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
            "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
            "\U0001FA00-\U0001FA6F"  # Chess Symbols
            "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
            "\U00002702-\U000027B0"  # Dingbats
            "\U000024C2-\U0001F251" 
            "]+", 
            flags=re.UNICODE
        )
        return emoji_pattern.sub(r'', text)
    return text  # Return the original value if it's not a string

# Apply the function to the 'Message' column
data['Message'] = data['Message'].apply(remove_emojis)

# Display the updated DataFrame
print(data.head())
# Out:
#                                        Channel Title Channel Username    ID  \
# 0  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2396
# 1  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2395
# 2  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2394
# 3  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2393
# 4  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI  2392
#
#                                              Message  \
# 0  ዛገ ይጀምራል\n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ               \...
# 1  \n#የሞያ ፈቃድ በቅርቡ ለምታሳድሱ               \n\n#CPD_...
# 2                                                  0
# 3  #Basic_Abdominal_Ultrasound_Training @#Hawassa...
# 4   እንዳያመልጥዎ \n#Obstetric_Ultrasound_Training#Add...
#
#                         Date              Media Path
# 0  2024-10-10 13:40:09+00:00  photos\@EAHCI_2396.jpg
# 1  2024-10-09 10:46:24+00:00  photos\@EAHCI_2395.jpg
# ...

# %%
data
# Out:
#                                           Channel Title    Channel Username  \
# 0     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 1     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 2     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 3     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 4     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# ...                                                 ...                 ...
# 3693                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3694                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3695                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3696                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3697                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
#
# ...

# %%
# Remove duplicate rows
data_cleaned = data.drop_duplicates()
data_cleaned
# Out:
#                                           Channel Title    Channel Username  \
# 0     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 1     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 2     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 3     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# 4     ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...              @EAHCI
# ...                                                 ...                 ...
# 3693                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3694                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3695                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3696                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
# 3697                     Lobelia pharmacy and cosmetics  @lobelia4cosmetics
#
# ...

# %%
path = os.path.join(rpath, 'data', 'clean_merged_data.csv')
data.to_csv(path, index=False)

# %%
from scripts.load_data import load_data_from_postgres, load_data_using_sqlalchemy,load_data_to_postgres

load_data_to_postgres(data)
# Out:
# An error occurred: could not translate host name "db" to address: No such host is known.

# %%
query = "SELECT * FROM user_satisfaction_scores;"  # Replace with your actual table name

# Load data from PostgreSQL
df = load_data_from_postgres(query)

# Display the first few rows of the dataframe
if df is not None:
    print("Successfully loaded the data")
else:
    print("Failed to load data.")
df
